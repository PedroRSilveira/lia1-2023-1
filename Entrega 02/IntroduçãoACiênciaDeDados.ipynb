# %% [markdown]
# <hr style="height:10px">
#
# <div class='container2'>
# 		<div>
# 			<img src='https://raw.githubusercontent.com/scadriano/lia1-2023-1/main/header.png' ALIGN='left' style='width:10em'>
# 		</div>
# 	<div style='padding: 0 7em 2em 12em;'>
# 	<h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div style="font-size:12pt;float:left;"> 2023/1 | 46M34 | Sala 200 CAE</div><br><br>
#     <div style="font-size:12pt;float:left;"><b>Projetos de Inteligência Artificial</b></div>
# 	</div>
# </div>
#
#
#  <hr style="height:5px">
#
#
# <h2>Preparação e Análise de Dados</h2>
#
# Notebook desenvolvido por: <a href="https://www.linkedin.com/in/pedro-rodrigues-silveira/">Pedro Rodrigues Silveira</a>
#
#  <hr style="height:2px">

# %% [markdown]
# # Carregar e exibir os dados da fonte

# %%
#Importar a biblioteca - Todos os projetos passarão pelo Numpy
import numpy as np

#Importar a biblioteca - Excel do Python
import pandas as pd

#Importar as bibliotecas - Visulizar dados
import seaborn as sns
import matplotlib.pyplot as plt

print ("Bibliotecas importadas com sucesso!")

#Instalação silenciosa
#!pip install -q numpy
# Out:
# Bibliotecas importadas com sucesso!

# %% [markdown]
# # Caracterização de dados
#
# Considere o conjunto de dados provenientes de um hospital denominado hospital.

# %%
#Importar o arquivo e guardar em um dataframe do Pandas
df_dataset = pd.read_csv ('/kaggle/input/hospital1/hospital.txt', sep = ',', index_col = None)

print("Dados importados com sucesso")
# Out:
# Dados importados com sucesso

# %%
#Exibir uma amostra do dataframe
display(df_dataset.head())
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0  4201     João     55    M    90  Concentradas  38.0           2     SP
# 1  3217    Maria     56    F    91  Inexistentes  39.5           4     MG
# 2  4039     Luiz     49    M    92    Espalhadas  38.0           2     RS
# 3  1920     José     57    M    93  Inexistentes  38.5           2     MG
# 4  4340  Cláudia     21    F    52     Uniformes  37.6           1     PE
#
#         Time Diagnóstico
# 0  Palmeiras      Doente
# 1   Cruzeiro      Doente
# 2     Grêmio    Saudável
# 3   Atlético      Doente
# 4      Sport    Saudável

# %%
#Exibir todo dataframe
display(df_dataset.head(n=8))
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0  4201     João     55    M    90  Concentradas  38.0           2     SP
# 1  3217    Maria     56    F    91  Inexistentes  39.5           4     MG
# 2  4039     Luiz     49    M    92    Espalhadas  38.0           2     RS
# 3  1920     José     57    M    93  Inexistentes  38.5           2     MG
# 4  4340  Cláudia     21    F    52     Uniformes  37.6           1     PE
# 5  2301      Ana     58    F    94  Inexistentes  38.0           3     RJ
# 6  1322    Marta     19    F    87    Espalhadas  39.0           3     AM
# 7  3027    Paulo     34    M    67     Uniformes  38.4           2     GO
#
#         Time Diagnóstico
# 0  Palmeiras      Doente
# 1   Cruzeiro      Doente
# 2     Grêmio    Saudável
# 3   Atlético      Doente
# 4      Sport    Saudável
# 5   Botafogo      Doente
# 6   Flamengo      Doente
# 7  Vila Nova    Saudável

# %% [markdown]
# Cada objeto corresponde a um paciente, sendo formado pelos atributos de entrada referentes ao paciente.
#
# Os atributos (identificação; nome; idade; sexo; peso; internação; estado; time; sintomas e resultados clínicos. Os sintomas são (manchas; e temperatura). O atributo alvo: diagnóstico. Esse atributo alvo é necessário em tarefas preditivas. Em tarefas descritivas é desnecessário!

# %%
df_dataset.groupby("Diagnóstico").count().plot.pie(y = "Internação")
# Out:
# <AxesSubplot: ylabel='Internação'>

# %%
df_dataset.groupby("Temp").count().plot.bar(y = "Internação")
# Out:
# <AxesSubplot: xlabel='Temp'>

# %%
df_dataset.groupby("Estado").count().plot.bar(y = "Internação")
# Out:
# <AxesSubplot: xlabel='Estado'>

# %%
sns.barplot(x = "Temp", y = "Internação", data = df_dataset)

plt.xlabel("Temperatura")
plt.ylabel("Internação")
plt.title("Gráfico de Internação em função da Temperatura")
# Out:
# Text(0.5, 1.0, 'Gráfico de Internação em função da Temperatura')

# %%
sns.barplot(x = "Estado", y = "Internação", data = df_dataset)

plt.xlabel("Estado")
plt.ylabel("Internação")
plt.title("Gráfico de Internação em função do Estado")
# Out:
# Text(0.5, 1.0, 'Gráfico de Internação em função do Estado')
